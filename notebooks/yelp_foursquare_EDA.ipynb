# %%
# imports
import os 
import pandas as pd
import requests
import json

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
file_path = r'C:\Users\amer_\Desktop\Statistical_modeling_python\data_files\citybike\citybike.csv'

df_citybike = pd.read_csv(file_path)

url = "https://api.foursquare.com/v3/places/search"
api_key = os.getenv("api_key")

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

results_list = []

for index, row in df_citybike.iterrows():
    params = {
        "query": "restaurant, school, university",
        "country": "Austria",
        "radius": 1000,
        "ll": f"{row['Latitude']},{row['Longitude']}",
        "sort": "DISTANCE",
    }
    
    response = requests.get(url, params=params, headers=headers)
    results = response.json()['results']
    results_list.append(results)

output_path = r'C:\Users\amer_\Desktop\Statistical_modeling_python\data_files\foursquare\json\foursquare_output2.json'
with open(output_path, 'w') as file:
    json.dump(results_list, file)

# %%
json_file_path = r'C:\Users\amer_\Desktop\Statistical_modeling_python\data_files\foursquare\json\foursquare_output2.json' 
with open(json_file_path, 'r') as file:
    results_list = json.load(file)

results_list
# Out:
# [[{'fsq_id': '4e4bf5621838fe3c818e780e',
#    'categories': [],
#    'chains': [],
#    'distance': 49,
#    'geocodes': {'main': {'latitude': 48.305158, 'longitude': 14.285047}},
#    'link': '/v3/places/4e4bf5621838fe3c818e780e',
#    'location': {'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Linz',
#     'locality': 'Linz',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Bar Absolut!on',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '78a54586e46a4fde404084dd',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13199,
#      'name': 'Indian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 75,
#    'geocodes': {'drop_off': {'latitude': 48.304985, 'longitude': 14.284522},
#     'main': {'latitude': 48.304891, 'longitude': 14.284415},
#     'roof': {'latitude': 48.304891, 'longitude': 14.284415}},
#    'link': '/v3/places/78a54586e46a4fde404084dd',
#    'location': {'address': 'Altstadt 16',
#     'country': 'AT',
#     'formatted_address': 'Altstadt 16, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'IKAAN Restaurant Bar Cafe',
#    'related_places': {}},
#   {'fsq_id': '8fca4722a2274823ba76f20e',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 139,
#    'geocodes': {'drop_off': {'latitude': 48.30642, 'longitude': 14.286043},
#     'main': {'latitude': 48.306419, 'longitude': 14.286042}},
#    'link': '/v3/places/8fca4722a2274823ba76f20e',
#    'location': {'address': 'Hauptplatz 12',
#     'country': 'AT',
#     'formatted_address': 'Hauptplatz 12, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'J. Leibetseder Restaurant- und BarbetriebsgmbH',
#    'related_places': {}},
#   {'fsq_id': '4bf6cb6eb1a7a59319b9d65b',
#    'categories': [{'id': 13099,
#      'name': 'Chinese Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 150,
#    'geocodes': {'main': {'latitude': 48.30645, 'longitude': 14.286628},
#     'roof': {'latitude': 48.30645, 'longitude': 14.286628}},
#    'link': '/v3/places/4bf6cb6eb1a7a59319b9d65b',
#    'location': {'address': 'Hauptplatz 4',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Hauptplatz 4, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'China-Restaurant Kim San',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '5b40a0caab2e4f78726f5de2',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 168,
#    'geocodes': {'drop_off': {'latitude': 48.304777, 'longitude': 14.286542},
#     'main': {'latitude': 48.304685, 'longitude': 14.28658},
#     'roof': {'latitude': 48.304685, 'longitude': 14.28658}},
#    'link': '/v3/places/5b40a0caab2e4f78726f5de2',
#    'location': {'address': 'Klosterstr. 1',
#     'country': 'AT',
#     'formatted_address': 'Klosterstr. 1, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Persia',
#    'related_places': {}},
#   {'fsq_id': '13d129561f2146fca1e7f942',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 168,
#    'geocodes': {'main': {'latitude': 48.304685, 'longitude': 14.28658},
#     'roof': {'latitude': 48.304685, 'longitude': 14.28658}},
#    'link': '/v3/places/13d129561f2146fca1e7f942',
#    'location': {'address': 'Klosterstr. 1',
#     'country': 'AT',
#     'formatted_address': 'Klosterstr. 1, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'China-Restaurant Singapore',
#    'related_places': {}},
#   {'fsq_id': '1a9ea5b5ffe1466d2576e343',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 175,
#    'geocodes': {'main': {'latitude': 48.306501, 'longitude': 14.286576},
#     'roof': {'latitude': 48.306501, 'longitude': 14.286576}},
#    'link': '/v3/places/1a9ea5b5ffe1466d2576e343',
#    'location': {'country': 'AT',
#     'formatted_address': '4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Cafe Paradiso, Das vegetarische Restaurant Bernhart + Braun',
#    'related_places': {}},
#   {'fsq_id': 'c1893a2a43574d511fc27310',
#    'categories': [{'id': 19015,
#      'name': 'Inn',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 180,
#    'geocodes': {'main': {'latitude': 48.306455, 'longitude': 14.286725},
#     'roof': {'latitude': 48.306455, 'longitude': 14.286725}},
#    'link': '/v3/places/c1893a2a43574d511fc27310',
#    'location': {'address': 'Hauptplatz 3',
#     'country': 'AT',
#     'formatted_address': 'Hauptplatz 3, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Blinis Cafe Restaurant Iris Fabiane Gastronomiebetriebs GmbH & Co',
#    'related_places': {}},
#   {'fsq_id': 'f08ac10d2eef4887995ae592',
#    'categories': [{'id': 13012,
#      'name': 'Hookah Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/hookahbar_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13145,
#      'name': 'Fast Food Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 185,
#    'geocodes': {'main': {'latitude': 48.304812, 'longitude': 14.286964},
#     'roof': {'latitude': 48.304812, 'longitude': 14.286964}},
#    'link': '/v3/places/f08ac10d2eef4887995ae592',
#    'location': {'address': 'Hauptplatz 25',
#     'country': 'AT',
#     'formatted_address': 'Hauptplatz 25, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Die Drei Etagen',
#    'related_places': {}},
#   {'fsq_id': '4b5b4dfff964a52026f328e3',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 195,
#    'geocodes': {'main': {'latitude': 48.30645, 'longitude': 14.286628},
#     'roof': {'latitude': 48.30645, 'longitude': 14.286628}},
#    'link': '/v3/places/4b5b4dfff964a52026f328e3',
#    'location': {'address': 'Hauptplatz 4',
#     'country': 'AT',
#     'formatted_address': 'Hauptplatz 4, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant-Cafe Alte Welt',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'}],
#  [{'fsq_id': '97575b6208da4f1f105cac5d',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 47,
#    'geocodes': {'main': {'latitude': 48.295204, 'longitude': 14.293178},
#     'roof': {'latitude': 48.295204, 'longitude': 14.293178}},
#    'link': '/v3/places/97575b6208da4f1f105cac5d',
#    'location': {'address': 'Landstr. 119',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 119, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Lebensfreude Cafe-Restaurant',
#    'related_places': {}},
#   {'fsq_id': 'bfb867b4b4374f76db8c8566',
#    'categories': [{'id': 13030,
#      'name': 'Buffet',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 105,
#    'geocodes': {'main': {'latitude': 48.294774, 'longitude': 14.294131},
#     'roof': {'latitude': 48.294774, 'longitude': 14.294131}},
#    'link': '/v3/places/bfb867b4b4374f76db8c8566',
#    'location': {'address': 'Blumauer Str. 2',
#     'country': 'AT',
#     'formatted_address': 'Blumauer Str. 2, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Kummerkasten - Steger Elfriede',
#    'related_places': {}},
#   {'fsq_id': '8064b19106ab40cce38f78cd',
#    'categories': [{'id': 13027,
#      'name': 'Bistro',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 137,
#    'geocodes': {'drop_off': {'latitude': 48.295223, 'longitude': 14.294468},
#     'main': {'latitude': 48.295378, 'longitude': 14.29444},
#     'roof': {'latitude': 48.295378, 'longitude': 14.29444}},
#    'link': '/v3/places/8064b19106ab40cce38f78cd',
#    'location': {'address': 'Blumauerstr. 9',
#     'country': 'AT',
#     'formatted_address': 'Blumauerstr. 9, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Cafe, Restaurant & Bar Yifeng MA',
#    'related_places': {}},
#   {'fsq_id': 'fc225bf95b874ef10e4013ba',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 141,
#    'geocodes': {'main': {'latitude': 48.293642, 'longitude': 14.292922},
#     'roof': {'latitude': 48.293642, 'longitude': 14.292922}},
#    'link': '/v3/places/fc225bf95b874ef10e4013ba',
#    'location': {'address': 'Bahnhofstr. 3',
#     'country': 'AT',
#     'formatted_address': 'Bahnhofstr. 3, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Drehscheibe',
#    'related_places': {}},
#   {'fsq_id': '83a9c5e249df4e619fc325f6',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 148,
#    'geocodes': {'drop_off': {'latitude': 48.296169, 'longitude': 14.292001},
#     'main': {'latitude': 48.296157, 'longitude': 14.291999}},
#    'link': '/v3/places/83a9c5e249df4e619fc325f6',
#    'location': {'address': 'Landstr. 17- 25/ P',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 17- 25/ P, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'MATADOO Restaurant- Betriebs',
#    'related_places': {}},
#   {'fsq_id': '4c4551278c1f20a1ada73d99',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13074,
#      'name': 'Austrian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/austrian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 193,
#    'geocodes': {'main': {'latitude': 48.295825, 'longitude': 14.294806},
#     'roof': {'latitude': 48.295825, 'longitude': 14.294806}},
#    'link': '/v3/places/4c4551278c1f20a1ada73d99',
#    'location': {'address': 'Südtiroler Str. 31',
#     'country': 'AT',
#     'formatted_address': 'Südtiroler Str. 31, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Kontrast Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '465aff3d23ad48086282a587',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 253,
#    'geocodes': {'drop_off': {'latitude': 48.296007, 'longitude': 14.289683},
#     'main': {'latitude': 48.29615, 'longitude': 14.289847},
#     'roof': {'latitude': 48.29615, 'longitude': 14.289847}},
#    'link': '/v3/places/465aff3d23ad48086282a587',
#    'location': {'address': 'Volksgartenstr. 19',
#     'country': 'AT',
#     'formatted_address': 'Volksgartenstr. 19, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Bauböck',
#    'related_places': {}},
#   {'fsq_id': '57dc71e1cd1077642490974c',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 421,
#    'geocodes': {'main': {'latitude': 48.298439, 'longitude': 14.290632}},
#    'link': '/v3/places/57dc71e1cd1077642490974c',
#    'location': {'address': 'Rainerstr. 2- 4',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Rainerstr. 2- 4, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Cuisino - das Restaurant im Casino Linz',
#    'related_places': {'parent': {'fsq_id': '4b991caff964a5201b6235e3',
#      'name': 'Casino Linz'}},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '4d7a20d678be594162dbaf70',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 437,
#    'geocodes': {'drop_off': {'latitude': 48.298029, 'longitude': 14.289199},
#     'main': {'latitude': 48.298047, 'longitude': 14.289349},
#     'roof': {'latitude': 48.298047, 'longitude': 14.289349}},
#    'link': '/v3/places/4d7a20d678be594162dbaf70',
#    'location': {'address': 'Gesellenhausstr. 7',
#     'country': 'AT',
#     'formatted_address': 'Gesellenhausstr. 7, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Kolping Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': 'b12ecfdb84104eae1a805559',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 455,
#    'geocodes': {'drop_off': {'latitude': 48.298598, 'longitude': 14.290558},
#     'main': {'latitude': 48.298753, 'longitude': 14.290582},
#     'roof': {'latitude': 48.298753, 'longitude': 14.290582}},
#    'link': '/v3/places/b12ecfdb84104eae1a805559',
#    'location': {'address': 'Langgasse 6',
#     'country': 'AT',
#     'formatted_address': 'Langgasse 6, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Weinhandel Josefine Pichler Inh Max Grisenti',
#    'related_places': {}}],
#  [{'fsq_id': 'cc329f76b028481766aa8179',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 103,
#    'geocodes': {'main': {'latitude': 48.290282, 'longitude': 14.291007},
#     'roof': {'latitude': 48.290282, 'longitude': 14.291007}},
#    'link': '/v3/places/cc329f76b028481766aa8179',
#    'location': {'address': 'Bahnhofplatz 3- 6',
#     'country': 'AT',
#     'formatted_address': 'Bahnhofplatz 3- 6, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'MATADOO Restaurant',
#    'related_places': {}},
#   {'fsq_id': '66e7bcfeadbd40d65996b9cd',
#    'categories': [{'id': 19000,
#      'name': 'Travel and Transportation',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 157,
#    'geocodes': {'main': {'latitude': 48.290772, 'longitude': 14.289169},
#     'roof': {'latitude': 48.290772, 'longitude': 14.289169}},
#    'link': '/v3/places/66e7bcfeadbd40d65996b9cd',
#    'location': {'address': 'Kärntner Str. 18- 20',
#     'country': 'AT',
#     'formatted_address': 'Kärntner Str. 18- 20, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurante Hotel Ibis Linz',
#    'related_places': {}},
#   {'fsq_id': '504a57bcd63efbbfd051a7d2',
#    'categories': [{'id': 13072,
#      'name': 'Asian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 192,
#    'geocodes': {'main': {'latitude': 48.290782, 'longitude': 14.288337},
#     'roof': {'latitude': 48.290782, 'longitude': 14.288337}},
#    'link': '/v3/places/504a57bcd63efbbfd051a7d2',
#    'location': {'address': 'Kärntnerstr. 26',
#     'country': 'AT',
#     'cross_street': 'im Wissensturm',
#     'formatted_address': 'Kärntnerstr. 26 (im Wissensturm), 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Niu Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': 'fc225bf95b874ef10e4013ba',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 299,
#    'geocodes': {'main': {'latitude': 48.293642, 'longitude': 14.292922},
#     'roof': {'latitude': 48.293642, 'longitude': 14.292922}},
#    'link': '/v3/places/fc225bf95b874ef10e4013ba',
#    'location': {'address': 'Bahnhofstr. 3',
#     'country': 'AT',
#     'formatted_address': 'Bahnhofstr. 3, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Drehscheibe',
#    'related_places': {}},
#   {'fsq_id': '4c7682e966be6dcb5549c30f',
#    'categories': [{'id': 12013,
#      'name': 'College and University',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 433,
#    'geocodes': {'main': {'latitude': 48.290835, 'longitude': 14.285301},
#     'roof': {'latitude': 48.290835, 'longitude': 14.285301}},
#    'link': '/v3/places/4c7682e966be6dcb5549c30f',
#    'location': {'address': 'Bergschlößlgasse 1',
#     'country': 'AT',
#     'formatted_address': 'Bergschlößlgasse 1, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'LIMAK Austrian Business School',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': 'bfb867b4b4374f76db8c8566',
#    'categories': [{'id': 13030,
#      'name': 'Buffet',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 452,
#    'geocodes': {'main': {'latitude': 48.294774, 'longitude': 14.294131},
#     'roof': {'latitude': 48.294774, 'longitude': 14.294131}},
#    'link': '/v3/places/bfb867b4b4374f76db8c8566',
#    'location': {'address': 'Blumauer Str. 2',
#     'country': 'AT',
#     'formatted_address': 'Blumauer Str. 2, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Kummerkasten - Steger Elfriede',
#    'related_places': {}},
#   {'fsq_id': '97575b6208da4f1f105cac5d',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 468,
#    'geocodes': {'main': {'latitude': 48.295204, 'longitude': 14.293178},
#     'roof': {'latitude': 48.295204, 'longitude': 14.293178}},
#    'link': '/v3/places/97575b6208da4f1f105cac5d',
#    'location': {'address': 'Landstr. 119',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 119, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Lebensfreude Cafe-Restaurant',
#    'related_places': {}},
#   {'fsq_id': '8064b19106ab40cce38f78cd',
#    'categories': [{'id': 13027,
#      'name': 'Bistro',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 522,
#    'geocodes': {'drop_off': {'latitude': 48.295223, 'longitude': 14.294468},
#     'main': {'latitude': 48.295378, 'longitude': 14.29444},
#     'roof': {'latitude': 48.295378, 'longitude': 14.29444}},
#    'link': '/v3/places/8064b19106ab40cce38f78cd',
#    'location': {'address': 'Blumauerstr. 9',
#     'country': 'AT',
#     'formatted_address': 'Blumauerstr. 9, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Cafe, Restaurant & Bar Yifeng MA',
#    'related_places': {}},
#   {'fsq_id': '83a9c5e249df4e619fc325f6',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 554,
#    'geocodes': {'drop_off': {'latitude': 48.296169, 'longitude': 14.292001},
#     'main': {'latitude': 48.296157, 'longitude': 14.291999}},
#    'link': '/v3/places/83a9c5e249df4e619fc325f6',
#    'location': {'address': 'Landstr. 17- 25/ P',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 17- 25/ P, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'MATADOO Restaurant- Betriebs',
#    'related_places': {}},
#   {'fsq_id': '465aff3d23ad48086282a587',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 559,
#    'geocodes': {'drop_off': {'latitude': 48.296007, 'longitude': 14.289683},
#     'main': {'latitude': 48.29615, 'longitude': 14.289847},
#     'roof': {'latitude': 48.29615, 'longitude': 14.289847}},
#    'link': '/v3/places/465aff3d23ad48086282a587',
#    'location': {'address': 'Volksgartenstr. 19',
#     'country': 'AT',
#     'formatted_address': 'Volksgartenstr. 19, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Bauböck',
#    'related_places': {}}],
#  [{'fsq_id': '5030083fd7204bd1d0dabbd8',
#    'categories': [{'id': 12053,
#      'name': 'Language School',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 40,
#    'geocodes': {'main': {'latitude': 48.302891, 'longitude': 14.289029},
#     'roof': {'latitude': 48.302891, 'longitude': 14.289029}},
#    'link': '/v3/places/5030083fd7204bd1d0dabbd8',
#    'location': {'address': 'Landstr. 24',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 24, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Inlingua Sprachschule - International School of Languages',
#    'related_places': {}},
#   {'fsq_id': '12fa2330585b4d0639cd39a9',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 79,
#    'geocodes': {'drop_off': {'latitude': 48.303693, 'longitude': 14.288494},
#     'main': {'latitude': 48.303606, 'longitude': 14.288402},
#     'roof': {'latitude': 48.303606, 'longitude': 14.288402}},
#    'link': '/v3/places/12fa2330585b4d0639cd39a9',
#    'location': {'address': 'Landstr. 12',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 12, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': "Restaurant s'Ringelg'spiel - Platzl's Schmankerl Reigen",
#    'related_places': {}},
#   {'fsq_id': 'd3a37bdec1fd412d299808dd',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 79,
#    'geocodes': {'main': {'latitude': 48.303911, 'longitude': 14.289119},
#     'roof': {'latitude': 48.303911, 'longitude': 14.289119}},
#    'link': '/v3/places/d3a37bdec1fd412d299808dd',
#    'location': {'address': 'Landstr. 13',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 13, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Sakura Japan-Restaurant',
#    'related_places': {}},
#   {'fsq_id': '5239e2f4498e0583c9696881',
#    'categories': [{'id': 13352,
#      'name': 'Thai Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 109,
#    'geocodes': {'drop_off': {'latitude': 48.303922, 'longitude': 14.29026},
#     'main': {'latitude': 48.304034, 'longitude': 14.290433},
#     'roof': {'latitude': 48.304034, 'longitude': 14.290433}},
#    'link': '/v3/places/5239e2f4498e0583c9696881',
#    'location': {'address': 'Marienstr. 11',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Marienstr. 11, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Coconut Thai Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '4e4aa080e4cd4fd73006b21a',
#    'categories': [{'id': 13074,
#      'name': 'Austrian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/austrian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 131,
#    'geocodes': {'main': {'latitude': 48.302212, 'longitude': 14.289312},
#     'roof': {'latitude': 48.302212, 'longitude': 14.289312}},
#    'link': '/v3/places/4e4aa080e4cd4fd73006b21a',
#    'location': {'address': 'Landstr. 30',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 30, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Klosterhof',
#    'related_places': {'children': []},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': 'cd6b7398db9f4d6faafc6693',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 145,
#    'geocodes': {'drop_off': {'latitude': 48.304537, 'longitude': 14.289861},
#     'main': {'latitude': 48.30448, 'longitude': 14.289772},
#     'roof': {'latitude': 48.30448, 'longitude': 14.289772}},
#    'link': '/v3/places/cd6b7398db9f4d6faafc6693',
#    'location': {'address': 'Marienstr. 5',
#     'country': 'AT',
#     'formatted_address': 'Marienstr. 5, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Goldener Drachen China- Restaurant Dun Shu FONG',
#    'related_places': {}},
#   {'fsq_id': '57651e04498ec3d136fdee7c',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}},
#     {'id': 13303,
#      'name': 'Mexican Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 156,
#    'geocodes': {'main': {'latitude': 48.302786, 'longitude': 14.29109},
#     'roof': {'latitude': 48.302786, 'longitude': 14.29109}},
#    'link': '/v3/places/57651e04498ec3d136fdee7c',
#    'location': {'address': 'OK Platz 1a',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'OK Platz 1a, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'El Paso Restaurant Pizzeria',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '8f7ebf7ead5e4af9cd759f32',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 199,
#    'geocodes': {'main': {'latitude': 48.304401, 'longitude': 14.287281},
#     'roof': {'latitude': 48.304401, 'longitude': 14.287281}},
#    'link': '/v3/places/8f7ebf7ead5e4af9cd759f32',
#    'location': {'address': 'Promenade 16',
#     'country': 'AT',
#     'formatted_address': 'Promenade 16, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Traxlmayr',
#    'related_places': {}},
#   {'fsq_id': '5bba21633c858d002cf7d16a',
#    'categories': [{'id': 13236,
#      'name': 'Italian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 201,
#    'geocodes': {'main': {'latitude': 48.302786, 'longitude': 14.29109},
#     'roof': {'latitude': 48.302786, 'longitude': 14.29109}},
#    'link': '/v3/places/5bba21633c858d002cf7d16a',
#    'location': {'address': 'Dametzstr. 38',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Dametzstr. 38, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'BIGOLI Bar - Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '919b73048b6b48a65520a668',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 217,
#    'geocodes': {'main': {'latitude': 48.302295, 'longitude': 14.2919},
#     'roof': {'latitude': 48.302295, 'longitude': 14.2919}},
#    'link': '/v3/places/919b73048b6b48a65520a668',
#    'location': {'address': 'Dametzstr. 39',
#     'country': 'AT',
#     'formatted_address': 'Dametzstr. 39, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Zur Goldhaube - Griechenland gruesst Linz',
#    'related_places': {}}],
#  [{'fsq_id': '4c4551278c1f20a1ada73d99',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13074,
#      'name': 'Austrian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/austrian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 35,
#    'geocodes': {'main': {'latitude': 48.295825, 'longitude': 14.294806},
#     'roof': {'latitude': 48.295825, 'longitude': 14.294806}},
#    'link': '/v3/places/4c4551278c1f20a1ada73d99',
#    'location': {'address': 'Südtiroler Str. 31',
#     'country': 'AT',
#     'formatted_address': 'Südtiroler Str. 31, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Kontrast Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '8064b19106ab40cce38f78cd',
#    'categories': [{'id': 13027,
#      'name': 'Bistro',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 68,
#    'geocodes': {'drop_off': {'latitude': 48.295223, 'longitude': 14.294468},
#     'main': {'latitude': 48.295378, 'longitude': 14.29444},
#     'roof': {'latitude': 48.295378, 'longitude': 14.29444}},
#    'link': '/v3/places/8064b19106ab40cce38f78cd',
#    'location': {'address': 'Blumauerstr. 9',
#     'country': 'AT',
#     'formatted_address': 'Blumauerstr. 9, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Cafe, Restaurant & Bar Yifeng MA',
#    'related_places': {}},
#   {'fsq_id': 'bfb867b4b4374f76db8c8566',
#    'categories': [{'id': 13030,
#      'name': 'Buffet',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 119,
#    'geocodes': {'main': {'latitude': 48.294774, 'longitude': 14.294131},
#     'roof': {'latitude': 48.294774, 'longitude': 14.294131}},
#    'link': '/v3/places/bfb867b4b4374f76db8c8566',
#    'location': {'address': 'Blumauer Str. 2',
#     'country': 'AT',
#     'formatted_address': 'Blumauer Str. 2, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Kummerkasten - Steger Elfriede',
#    'related_places': {}},
#   {'fsq_id': '97575b6208da4f1f105cac5d',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 163,
#    'geocodes': {'main': {'latitude': 48.295204, 'longitude': 14.293178},
#     'roof': {'latitude': 48.295204, 'longitude': 14.293178}},
#    'link': '/v3/places/97575b6208da4f1f105cac5d',
#    'location': {'address': 'Landstr. 119',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 119, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Lebensfreude Cafe-Restaurant',
#    'related_places': {}},
#   {'fsq_id': '83a9c5e249df4e619fc325f6',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 258,
#    'geocodes': {'drop_off': {'latitude': 48.296169, 'longitude': 14.292001},
#     'main': {'latitude': 48.296157, 'longitude': 14.291999}},
#    'link': '/v3/places/83a9c5e249df4e619fc325f6',
#    'location': {'address': 'Landstr. 17- 25/ P',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 17- 25/ P, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'MATADOO Restaurant- Betriebs',
#    'related_places': {}},
#   {'fsq_id': 'fc225bf95b874ef10e4013ba',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 271,
#    'geocodes': {'main': {'latitude': 48.293642, 'longitude': 14.292922},
#     'roof': {'latitude': 48.293642, 'longitude': 14.292922}},
#    'link': '/v3/places/fc225bf95b874ef10e4013ba',
#    'location': {'address': 'Bahnhofstr. 3',
#     'country': 'AT',
#     'formatted_address': 'Bahnhofstr. 3, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Drehscheibe',
#    'related_places': {}},
#   {'fsq_id': '465aff3d23ad48086282a587',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 413,
#    'geocodes': {'drop_off': {'latitude': 48.296007, 'longitude': 14.289683},
#     'main': {'latitude': 48.29615, 'longitude': 14.289847},
#     'roof': {'latitude': 48.29615, 'longitude': 14.289847}},
#    'link': '/v3/places/465aff3d23ad48086282a587',
#    'location': {'address': 'Volksgartenstr. 19',
#     'country': 'AT',
#     'formatted_address': 'Volksgartenstr. 19, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Bauböck',
#    'related_places': {}},
#   {'fsq_id': '557c0b9c498eee5420b4074a',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 418,
#    'geocodes': {'main': {'latitude': 48.292342, 'longitude': 14.29867},
#     'roof': {'latitude': 48.292342, 'longitude': 14.29867}},
#    'link': '/v3/places/557c0b9c498eee5420b4074a',
#    'location': {'address': 'Anzengruberstr. 18',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Anzengruberstr. 18, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Cafe Restaurant Leiner',
#    'related_places': {'parent': {'fsq_id': '4cadd1798b57a1cd8ff29a75',
#      'name': 'Leiner'}},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '0fe3a0c3e4bb4b6eb4095551',
#    'categories': [{'id': 13236,
#      'name': 'Italian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 452,
#    'geocodes': {'main': {'latitude': 48.298912, 'longitude': 14.298646},
#     'roof': {'latitude': 48.298912, 'longitude': 14.298646}},
#    'link': '/v3/places/0fe3a0c3e4bb4b6eb4095551',
#    'location': {'address': 'Schillerstr. 52',
#     'country': 'AT',
#     'formatted_address': 'Schillerstr. 52, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Balaton Restaurant',
#    'related_places': {}},
#   {'fsq_id': '57dc71e1cd1077642490974c',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 479,
#    'geocodes': {'main': {'latitude': 48.298439, 'longitude': 14.290632}},
#    'link': '/v3/places/57dc71e1cd1077642490974c',
#    'location': {'address': 'Rainerstr. 2- 4',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Rainerstr. 2- 4, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Cuisino - das Restaurant im Casino Linz',
#    'related_places': {'parent': {'fsq_id': '4b991caff964a5201b6235e3',
#      'name': 'Casino Linz'}},
#    'timezone': 'Europe/Vienna'}],
#  [{'fsq_id': '7aebe5a6f61c41497052191e',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 43,
#    'geocodes': {'drop_off': {'latitude': 48.308129, 'longitude': 14.289426},
#     'main': {'latitude': 48.308146, 'longitude': 14.28942}},
#    'link': '/v3/places/7aebe5a6f61c41497052191e',
#    'location': {'address': 'Untere Donaulaende 11',
#     'country': 'AT',
#     'formatted_address': 'Untere Donaulaende 11, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Parkbad Bueffet',
#    'related_places': {}},
#   {'fsq_id': '4bbe19fcfc0fd13a8deca150',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13003,
#      'name': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 74,
#    'geocodes': {'main': {'latitude': 48.308948, 'longitude': 14.289424},
#     'roof': {'latitude': 48.308948, 'longitude': 14.289424}},
#    'link': '/v3/places/4bbe19fcfc0fd13a8deca150',
#    'location': {'address': 'Ernst-Koref-Promenade 1',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Ernst-Koref-Promenade 1, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Cafe Bar Restaurant Lentos',
#    'related_places': {'parent': {'fsq_id': '4c091fd07e3fc928bf5ff182',
#      'name': 'Lentos Kunstmuseum'}},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '4eb8111782313162705ab79e',
#    'categories': [{'id': 13177,
#      'name': 'Greek Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 155,
#    'geocodes': {'main': {'latitude': 48.306624, 'longitude': 14.28789},
#     'roof': {'latitude': 48.306624, 'longitude': 14.28789}},
#    'link': '/v3/places/4eb8111782313162705ab79e',
#    'location': {'address': 'Neutorgasse 3',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Neutorgasse 3, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Sorbas Taverne',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': 'ee8e42b4f3d94be502eaa486',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 166,
#    'geocodes': {'main': {'latitude': 48.307186, 'longitude': 14.287418},
#     'roof': {'latitude': 48.307186, 'longitude': 14.287418}},
#    'link': '/v3/places/ee8e42b4f3d94be502eaa486',
#    'location': {'address': 'Adalbert-Stifter-Platz 2',
#     'country': 'AT',
#     'formatted_address': 'Adalbert-Stifter-Platz 2, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Yoko Sushi-Restaurant',
#    'related_places': {}},
#   {'fsq_id': '4b953aeef964a5209c9634e3',
#    'categories': [{'id': 13099,
#      'name': 'Chinese Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}},
#     {'id': 13352,
#      'name': 'Thai Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#       'suffix': '.png'}},
#     {'id': 13379,
#      'name': 'Vietnamese Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 168,
#    'geocodes': {'main': {'latitude': 48.307135, 'longitude': 14.28747},
#     'roof': {'latitude': 48.307135, 'longitude': 14.28747}},
#    'link': '/v3/places/4b953aeef964a5209c9634e3',
#    'location': {'address': 'Adalbert-Stifter-Platz 2',
#     'country': 'AT',
#     'formatted_address': 'Adalbert-Stifter-Platz 2, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'China- Restaurant Goldene Pagode',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '4b5b2be1f964a52068e828e3',
#    'categories': [{'id': 13199,
#      'name': 'Indian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 170,
#    'geocodes': {'drop_off': {'latitude': 48.306829, 'longitude': 14.287579},
#     'main': {'latitude': 48.306715, 'longitude': 14.287591},
#     'roof': {'latitude': 48.306715, 'longitude': 14.287591}},
#    'link': '/v3/places/4b5b2be1f964a52068e828e3',
#    'location': {'address': 'Adlergasse 14',
#     'country': 'AT',
#     'formatted_address': 'Adlergasse 14, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Indisches Restaurant TAJ MAHAL',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '149f93b223004f839f3837b2',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 175,
#    'geocodes': {'main': {'latitude': 48.30708, 'longitude': 14.287424},
#     'roof': {'latitude': 48.30708, 'longitude': 14.287424}},
#    'link': '/v3/places/149f93b223004f839f3837b2',
#    'location': {'address': 'Adalbert-Stifter-Platz 2',
#     'country': 'AT',
#     'formatted_address': 'Adalbert-Stifter-Platz 2, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant II Leonetto',
#    'related_places': {}},
#   {'fsq_id': '4d766e96ac39721e50daa113',
#    'categories': [{'id': 13030,
#      'name': 'Buffet',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13099,
#      'name': 'Chinese Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}},
#     {'id': 13276,
#      'name': 'Sushi Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 191,
#    'geocodes': {'main': {'latitude': 48.30662, 'longitude': 14.289848},
#     'roof': {'latitude': 48.30662, 'longitude': 14.289848}},
#    'link': '/v3/places/4d766e96ac39721e50daa113',
#    'location': {'address': 'Pfarrplatz 11',
#     'country': 'AT',
#     'cross_street': '',
#     'formatted_address': 'Pfarrplatz 11, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'China-Restaurant Jin Lu',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '1173fdc2877e45396c13cafd',
#    'categories': [{'id': 13177,
#      'name': 'Greek Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 206,
#    'geocodes': {'main': {'latitude': 48.306564, 'longitude': 14.289802},
#     'roof': {'latitude': 48.306564, 'longitude': 14.289802}},
#    'link': '/v3/places/1173fdc2877e45396c13cafd',
#    'location': {'address': 'Pfarrplatz 11',
#     'country': 'AT',
#     'formatted_address': 'Pfarrplatz 11, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Alt Athen',
#    'related_places': {}},
#   {'fsq_id': '4b5b4dfff964a52026f328e3',
#    'categories': [{'id': 13000,
#      'name': 'Dining and Drinking',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 246,
#    'geocodes': {'main': {'latitude': 48.30645, 'longitude': 14.286628},
#     'roof': {'latitude': 48.30645, 'longitude': 14.286628}},
#    'link': '/v3/places/4b5b4dfff964a52026f328e3',
#    'location': {'address': 'Hauptplatz 4',
#     'country': 'AT',
#     'formatted_address': 'Hauptplatz 4, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant-Cafe Alte Welt',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'}],
#  [{'fsq_id': 'e96dbd0f74f74178f7961757',
#    'categories': [{'id': 13177,
#      'name': 'Greek Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 196,
#    'geocodes': {'main': {'latitude': 48.310412, 'longitude': 14.292865},
#     'roof': {'latitude': 48.310412, 'longitude': 14.292865}},
#    'link': '/v3/places/e96dbd0f74f74178f7961757',
#    'location': {'address': 'Untere Donaulände 7',
#     'country': 'AT',
#     'formatted_address': 'Untere Donaulände 7, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Anklang',
#    'related_places': {}},
#   {'fsq_id': '7aebe5a6f61c41497052191e',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
# ...
#    'link': '/v3/places/b12ecfdb84104eae1a805559',
#    'location': {'address': 'Langgasse 6',
#     'country': 'AT',
#     'formatted_address': 'Langgasse 6, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Weinhandel Josefine Pichler Inh Max Grisenti',
#    'related_places': {}},
#   {'fsq_id': '97575b6208da4f1f105cac5d',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 477,
#    'geocodes': {'main': {'latitude': 48.295204, 'longitude': 14.293178},
#     'roof': {'latitude': 48.295204, 'longitude': 14.293178}},
#    'link': '/v3/places/97575b6208da4f1f105cac5d',
#    'location': {'address': 'Landstr. 119',
#     'country': 'AT',
#     'formatted_address': 'Landstr. 119, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Lebensfreude Cafe-Restaurant',
#    'related_places': {}},
#   {'fsq_id': 'a568ca06cba54d2d54b290c3',
#    'categories': [{'id': 13029,
#      'name': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 499,
#    'geocodes': {'drop_off': {'latitude': 48.299696, 'longitude': 14.289872},
#     'main': {'latitude': 48.299625, 'longitude': 14.289897},
#     'roof': {'latitude': 48.299625, 'longitude': 14.289897}},
#    'link': '/v3/places/a568ca06cba54d2d54b290c3',
#    'location': {'address': 'Magazingasse 10',
#     'country': 'AT',
#     'formatted_address': 'Magazingasse 10, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Chindia China & India',
#    'related_places': {}},
#   {'fsq_id': 'a75f002b95bd4d9b6a9349ad',
#    'categories': [{'id': 13302,
#      'name': 'Mediterranean Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#       'suffix': '.png'}},
#     {'id': 13356,
#      'name': 'Turkish Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 506,
#    'geocodes': {'drop_off': {'latitude': 48.299716, 'longitude': 14.28993},
#     'main': {'latitude': 48.299681, 'longitude': 14.289943},
#     'roof': {'latitude': 48.299681, 'longitude': 14.289943}},
#    'link': '/v3/places/a75f002b95bd4d9b6a9349ad',
#    'location': {'address': 'Magazingasse 11',
#     'country': 'AT',
#     'formatted_address': 'Magazingasse 11, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Cafe Restaurant Antebia Mediterran',
#    'related_places': {}},
#   {'fsq_id': 'fc225bf95b874ef10e4013ba',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 507,
#    'geocodes': {'main': {'latitude': 48.293642, 'longitude': 14.292922},
#     'roof': {'latitude': 48.293642, 'longitude': 14.292922}},
#    'link': '/v3/places/fc225bf95b874ef10e4013ba',
#    'location': {'address': 'Bahnhofstr. 3',
#     'country': 'AT',
#     'formatted_address': 'Bahnhofstr. 3, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Drehscheibe',
#    'related_places': {}},
#   {'fsq_id': '4c7682e966be6dcb5549c30f',
#    'categories': [{'id': 12013,
#      'name': 'College and University',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 549,
#    'geocodes': {'main': {'latitude': 48.290835, 'longitude': 14.285301},
#     'roof': {'latitude': 48.290835, 'longitude': 14.285301}},
#    'link': '/v3/places/4c7682e966be6dcb5549c30f',
#    'location': {'address': 'Bergschlößlgasse 1',
#     'country': 'AT',
#     'formatted_address': 'Bergschlößlgasse 1, 4020 Linz',
#     'locality': 'Linz',
#     'postcode': '4020',
#     'region': 'Oberösterreich'},
#    'name': 'LIMAK Austrian Business School',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'}],
#  [{'fsq_id': '65db0326ea7348fed2de154f',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 514,
#    'geocodes': {'drop_off': {'latitude': 48.25078, 'longitude': 14.321226},
#     'main': {'latitude': 48.250804, 'longitude': 14.320694},
#     'roof': {'latitude': 48.250804, 'longitude': 14.320694}},
#    'link': '/v3/places/65db0326ea7348fed2de154f',
#    'location': {'address': 'Saporoshjestr. 3',
#     'country': 'AT',
#     'formatted_address': 'Saporoshjestr. 3, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Kaffeehaus, Bar-Cafe, Restaurant Schörgi s Cafe',
#    'related_places': {}},
#   {'fsq_id': '4d54098f8c39cbff606f5a80',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 540,
#    'geocodes': {'main': {'latitude': 48.25072, 'longitude': 14.325198},
#     'roof': {'latitude': 48.25072, 'longitude': 14.325198}},
#    'link': '/v3/places/4d54098f8c39cbff606f5a80',
#    'location': {'address': 'Wiener Str. 441',
#     'country': 'AT',
#     'formatted_address': 'Wiener Str. 441, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Löwenfeld Restaurant',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': 'd60e96ba8b9f4bcfd2042d79',
#    'categories': [{'id': 13027,
#      'name': 'Bistro',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 861,
#    'geocodes': {'main': {'latitude': 48.254632, 'longitude': 14.311142},
#     'roof': {'latitude': 48.254632, 'longitude': 14.311142}},
#    'link': '/v3/places/d60e96ba8b9f4bcfd2042d79',
#    'location': {'address': 'Pestalozzistr. 92',
#     'country': 'AT',
#     'formatted_address': 'Pestalozzistr. 92, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Donauplatz Cafe Pub Restaurant',
#    'related_places': {}}],
#  [{'fsq_id': 'eccfd9a356c34505c621f18a',
#    'categories': [{'id': 19015,
#      'name': 'Inn',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 457,
#    'geocodes': {'drop_off': {'latitude': 48.246129, 'longitude': 14.333069},
#     'main': {'latitude': 48.246007, 'longitude': 14.333185},
#     'roof': {'latitude': 48.246007, 'longitude': 14.333185}},
#    'link': '/v3/places/eccfd9a356c34505c621f18a',
#    'location': {'address': 'Ebelsberger Schloßweg 22',
#     'country': 'AT',
#     'formatted_address': 'Ebelsberger Schloßweg 22, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Pferdehof Restaurant & Cafe',
#    'related_places': {}},
#   {'fsq_id': '5268bbd53557443f75fb84f7',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 547,
#    'geocodes': {'main': {'latitude': 48.24731, 'longitude': 14.341719},
#     'roof': {'latitude': 48.24731, 'longitude': 14.341719}},
#    'link': '/v3/places/5268bbd53557443f75fb84f7',
#    'location': {'address': 'Traundorfer Str. 8',
#     'country': 'AT',
#     'formatted_address': 'Traundorfer Str. 8, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant z Husaren',
#    'related_places': {}},
#   {'fsq_id': '4c459866f799e21e8d5cafa2',
#    'categories': [{'id': 13026,
#      'name': 'BBQ Joint',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 651,
#    'geocodes': {'main': {'latitude': 48.244087, 'longitude': 14.329184},
#     'roof': {'latitude': 48.244087, 'longitude': 14.329184}},
#    'link': '/v3/places/4c459866f799e21e8d5cafa2',
#    'location': {'address': 'Kremsmünsterer Str. 1- 3',
#     'country': 'AT',
#     'formatted_address': 'Kremsmünsterer Str. 1- 3, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Volkshaus Ebelsberg',
#    'related_places': {},
#    'timezone': 'Europe/Vienna'},
#   {'fsq_id': '84cdf3f167954a6846ec3ba2',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 884,
#    'geocodes': {'main': {'latitude': 48.246198, 'longitude': 14.326622},
#     'roof': {'latitude': 48.246198, 'longitude': 14.326622}},
#    'link': '/v3/places/84cdf3f167954a6846ec3ba2',
#    'location': {'address': 'Wambacher Str. 50/1',
#     'country': 'AT',
#     'formatted_address': 'Wambacher Str. 50/1, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant Pussy Cat',
#    'related_places': {}}],
#  [{'fsq_id': '5268bbd53557443f75fb84f7',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 266,
#    'geocodes': {'main': {'latitude': 48.24731, 'longitude': 14.341719},
#     'roof': {'latitude': 48.24731, 'longitude': 14.341719}},
#    'link': '/v3/places/5268bbd53557443f75fb84f7',
#    'location': {'address': 'Traundorfer Str. 8',
#     'country': 'AT',
#     'formatted_address': 'Traundorfer Str. 8, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant z Husaren',
#    'related_places': {}},
#   {'fsq_id': 'eccfd9a356c34505c621f18a',
#    'categories': [{'id': 19015,
#      'name': 'Inn',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 669,
#    'geocodes': {'drop_off': {'latitude': 48.246129, 'longitude': 14.333069},
#     'main': {'latitude': 48.246007, 'longitude': 14.333185},
#     'roof': {'latitude': 48.246007, 'longitude': 14.333185}},
#    'link': '/v3/places/eccfd9a356c34505c621f18a',
#    'location': {'address': 'Ebelsberger Schloßweg 22',
#     'country': 'AT',
#     'formatted_address': 'Ebelsberger Schloßweg 22, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Pferdehof Restaurant & Cafe',
#    'related_places': {}}],
#  [{'fsq_id': '0fe7278fd2ca4637c4d583bb',
#    'categories': [{'id': 13072,
#      'name': 'Asian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 59,
#    'geocodes': {'drop_off': {'latitude': 48.257568, 'longitude': 14.360575},
#     'main': {'latitude': 48.257436, 'longitude': 14.360577},
#     'roof': {'latitude': 48.257436, 'longitude': 14.360577}},
#    'link': '/v3/places/0fe7278fd2ca4637c4d583bb',
#    'location': {'address': 'Lunaplatz 7- 9',
#     'country': 'AT',
#     'formatted_address': 'Lunaplatz 7- 9, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Restaurant & Bar Yifeng MA',
#    'related_places': {}}],
#  [{'fsq_id': '5268bbd53557443f75fb84f7',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 631,
#    'geocodes': {'main': {'latitude': 48.24731, 'longitude': 14.341719},
#     'roof': {'latitude': 48.24731, 'longitude': 14.341719}},
#    'link': '/v3/places/5268bbd53557443f75fb84f7',
#    'location': {'address': 'Traundorfer Str. 8',
#     'country': 'AT',
#     'formatted_address': 'Traundorfer Str. 8, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'Restaurant z Husaren',
#    'related_places': {}}],
#  [{'fsq_id': '0fe7278fd2ca4637c4d583bb',
#    'categories': [{'id': 13072,
#      'name': 'Asian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 360,
#    'geocodes': {'drop_off': {'latitude': 48.257568, 'longitude': 14.360575},
#     'main': {'latitude': 48.257436, 'longitude': 14.360577},
#     'roof': {'latitude': 48.257436, 'longitude': 14.360577}},
#    'link': '/v3/places/0fe7278fd2ca4637c4d583bb',
#    'location': {'address': 'Lunaplatz 7- 9',
#     'country': 'AT',
#     'formatted_address': 'Lunaplatz 7- 9, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Restaurant & Bar Yifeng MA',
#    'related_places': {}}],
#  [{'fsq_id': '0fe7278fd2ca4637c4d583bb',
#    'categories': [{'id': 13072,
#      'name': 'Asian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 636,
#    'geocodes': {'drop_off': {'latitude': 48.257568, 'longitude': 14.360575},
#     'main': {'latitude': 48.257436, 'longitude': 14.360577},
#     'roof': {'latitude': 48.257436, 'longitude': 14.360577}},
#    'link': '/v3/places/0fe7278fd2ca4637c4d583bb',
#    'location': {'address': 'Lunaplatz 7- 9',
#     'country': 'AT',
#     'formatted_address': 'Lunaplatz 7- 9, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Restaurant & Bar Yifeng MA',
#    'related_places': {}}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'fsq_id': '0fe7278fd2ca4637c4d583bb',
#    'categories': [{'id': 13072,
#      'name': 'Asian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 611,
#    'geocodes': {'drop_off': {'latitude': 48.257568, 'longitude': 14.360575},
#     'main': {'latitude': 48.257436, 'longitude': 14.360577},
#     'roof': {'latitude': 48.257436, 'longitude': 14.360577}},
#    'link': '/v3/places/0fe7278fd2ca4637c4d583bb',
#    'location': {'address': 'Lunaplatz 7- 9',
#     'country': 'AT',
#     'formatted_address': 'Lunaplatz 7- 9, 4030 Linz',
#     'locality': 'Linz',
#     'postcode': '4030',
#     'region': 'Oberösterreich'},
#    'name': 'City Wok Restaurant & Bar Yifeng MA',
#    'related_places': {}}]]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
json_file_path = r'C:\Users\amer_\Desktop\Statistical_modeling_python\data_files\foursquare\json\foursquare_output2.json' 

with open(json_file_path, 'r') as file:
    results_list = json.load(file)

foursquare_data = results_list
# Existing code...

N_A = "N/A"  # to return "not available" if it doesn't exist
places = []
postcode = None 

for item in foursquare_data:
    for item1 in item:
        fsq_id = item1['fsq_id']
        name = item1['name']
        country = item1['location']['country']
        latitude = item1['geocodes']['main']['latitude']
        longitude = item1['geocodes']['main']['longitude']
        distance = item1['distance']
        if 'locality' in item1['location']:
            city = item1['location']['locality']
        else: 
            city = N_A
        
        if 'postcode' in item1['location']:
            try:
                postcode = int(item1['location']['postcode'])  # Convert to integer
            except ValueError:
                postcode = None  # Handle cases where postcode is not a valid integer
            
        if 'address' in item1['location']:
            address = item1['location']['address']
        elif 'formatted_address' in item1['location']:
            address = item1['location']['formatted_address']
            
        categories = []
        for category in item1['categories']:
            category_name = category['name']
            if category_name == "":
                categories = ["N/A"]
            else:
                categories.append(category_name)
        
        categories_str = ', '.join(categories)
            
        places.append({
            'name': name,
            'distance': distance,
            'address': address,
            'zip_code': postcode,
            'city': city,
            'latitude': latitude,
            'longitude': longitude,
            'categories': categories_str
        })

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df_foursquare_pre = pd.DataFrame(places)
df_foursquare = df_foursquare_pre.drop_duplicates('name')
df_foursquare
# Out:
#                                                name  distance  \
# 0                         Restaurant Bar Absolut!on        49
# 1                         IKAAN Restaurant Bar Cafe        75
# 2    J. Leibetseder Restaurant- und BarbetriebsgmbH       139
# 3                          China-Restaurant Kim San       150
# 4                                 Restaurant Persia       168
# ..                                              ...       ...
# 416                     Pferdehof Restaurant & Cafe       457
# 417                            Restaurant z Husaren       547
# 418                  Restaurant Volkshaus Ebelsberg       651
# 419                            Restaurant Pussy Cat       884
# 422             City Wok Restaurant & Bar Yifeng MA        59
#
#                       address  zip_code  city   latitude  longitude  \
# 0                        Linz       NaN  Linz  48.305158  14.285047
# 1                 Altstadt 16    4020.0  Linz  48.304891  14.284415
# 2               Hauptplatz 12    4020.0  Linz  48.306419  14.286042
# 3                Hauptplatz 4    4020.0  Linz  48.306450  14.286628
# 4               Klosterstr. 1    4020.0  Linz  48.304685  14.286580
# ..                        ...       ...   ...        ...        ...
# 416  Ebelsberger Schloßweg 22    4030.0  Linz  48.246007  14.333185
# 417        Traundorfer Str. 8    4030.0  Linz  48.247310  14.341719
# 418  Kremsmünsterer Str. 1- 3    4030.0  Linz  48.244087  14.329184
# 419       Wambacher Str. 50/1    4030.0  Linz  48.246198  14.326622
# 422            Lunaplatz 7- 9    4030.0  Linz  48.257436  14.360577
#
#                   categories
# 0
# 1    Café, Indian Restaurant
# 2                 Restaurant
# 3         Chinese Restaurant
# 4                 Restaurant
# ..                       ...
# 416                      Inn
# 417         Café, Restaurant
# 418         BBQ Joint, Diner
# 419               Restaurant
# 422         Asian Restaurant
#
# [89 rows x 8 columns]

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
directory = r'C:\Users\amer_\Desktop\Statistical_modeling_python\data_files\yelp\json' #replace with your own directory
os.makedirs(directory, exist_ok=True)
yelp_api = os.getenv('yelp_api')

all_responses = []  # List to store all JSON responses

for index, row in df_citybike.iterrows():
    url = f"https://api.yelp.com/v3/businesses/search?latitude={row['Latitude']}&longitude={row['Longitude']}&sort_by=best_match&limit=20"

    headers = {
        "accept": "application/json",
        "Authorization": f"bearer {yelp_api}"
    }
    params = {
        'location': 'Linz, Austria',
        'categories': 'restaurant, bar, university, school',
        'radius' : 1000
    }

    response = requests.get(url, headers=headers)
    response_data = response.json()
    all_responses.append(response_data)

# Save all_responses to a single JSON file
path_file2 = r'C:\Users\amer_\Downloads'
output_file = os.path.join(path_file2, 'all_responses.json')
with open(output_file, 'w') as file:
    json.dump(all_responses, file)

    print(response.text)
# Out:
# {"businesses": [{"id": "KnXFQ3Kn6NWZg6TOoZr1oA", "alias": "city-wok-linz", "name": "City Wok", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/A5Sb1uiKsY3HazkXsVlf5g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/city-wok-linz?adjust_creative=oTMM45yX8Bu5dJym9wWymQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oTMM45yX8Bu5dJym9wWymQ", "review_count": 5, "categories": [{"alias": "chinese", "title": "Chinese"}, {"alias": "bars", "title": "Bars"}], "rating": 4.0, "coordinates": {"latitude": 48.2573395, "longitude": 14.3606005}, "transactions": [], "price": "\u20ac\u20ac\u20ac\u20ac", "location": {"address1": "Lunaplatz 7", "address2": "", "address3": "", "city": "Linz", "zip_code": "4030", "country": "AT", "state": "4", "display_address": ["Lunaplatz 7", "4030 Linz", "Austria"]}, "phone": "+43732321164", "display_phone": "+43 732 321164", "distance": 618.4318448012164}, {"id": "OPIHwGmO2ZQkwjYEsm4PDA", "alias": "ristorante-leonardo-linz", "name": "Ristorante Leonardo", "image_url": "", "is_closed": false, "url": "https://www.yelp.com/biz/ristorante-leonardo-linz?adjust_creative=oTMM45yX8Bu5dJym9wWymQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oTMM45yX8Bu5dJym9wWymQ", "review_count": 3, "categories": [{"alias": "italian", "title": "Italian"}], "rating": 4.0, "coordinates": {"latitude": 48.257783, "longitude": 14.360584}, "transactions": [], "price": "\u20ac\u20ac", "location": {"address1": "Lunaplatz  9", "address2": "Solar City", "address3": null, "city": "Linz", "zip_code": "4030", "country": "AT", "state": "4", "display_address": ["Lunaplatz  9", "Solar City", "4030 Linz", "Austria"]}, "phone": "+43732918181", "display_phone": "+43 732 918181", "distance": 647.9848915103677}, {"id": "cLBtHwwjgkcFFHTU1dSnjg", "alias": "gasthof-zum-hauermandl-linz", "name": "Gasthof zum Hauermandl", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/vh4b6GDpwBC8KAS4BcwnEg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/gasthof-zum-hauermandl-linz?adjust_creative=oTMM45yX8Bu5dJym9wWymQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oTMM45yX8Bu5dJym9wWymQ", "review_count": 3, "categories": [{"alias": "wine_bars", "title": "Wine Bars"}, {"alias": "guesthouses", "title": "Guest Houses"}, {"alias": "austrian", "title": "Austrian"}], "rating": 4.5, "coordinates": {"latitude": 48.2451779, "longitude": 14.3704803}, "transactions": [], "location": {"address1": "Oidener Str. 98", "address2": null, "address3": null, "city": "Linz", "zip_code": "4030", "country": "AT", "state": "4", "display_address": ["Oidener Str. 98", "4030 Linz", "Austria"]}, "phone": "+43732320213", "display_phone": "+43 732 320213", "distance": 1236.067327642669}, {"id": "HzSLRlhsXP-XZYQ5HIGSmA", "alias": "gasthaus-petersburg-linz", "name": "Gasthaus Petersburg", "image_url": "", "is_closed": false, "url": "https://www.yelp.com/biz/gasthaus-petersburg-linz?adjust_creative=oTMM45yX8Bu5dJym9wWymQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oTMM45yX8Bu5dJym9wWymQ", "review_count": 1, "categories": [{"alias": "austrian", "title": "Austrian"}], "rating": 5.0, "coordinates": {"latitude": 48.2463, "longitude": 14.3273}, "transactions": [], "price": "\u20ac\u20ac", "location": {"address1": "Fadingerplatz 6", "address2": null, "address3": null, "city": "Linz", "zip_code": "4030", "country": "AT", "state": "4", "display_address": ["Fadingerplatz 6", "4030 Linz", "Austria"]}, "phone": "+436505555855", "display_phone": "+43 650 5555855", "distance": 2344.128575207952}, {"id": "tLhN6QEXPj3OcAmp4CfD0g", "alias": "restaurant-l\u00f6wenfeld-linz", "name": "Restaurant L\u00f6wenfeld", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Qjq3q_bNFawO3Czbg9kt7Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/restaurant-l%C3%B6wenfeld-linz?adjust_creative=oTMM45yX8Bu5dJym9wWymQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oTMM45yX8Bu ...

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
json_file_path = r'C:\Users\amer_\Desktop\Statistical_modeling_python\data_files\yelp\json\all_responses.json'
# all_responses is from the previous cell. the json_file_path is just to specify in case of a crash of VScode
with open(json_file_path, 'r') as file:
    all_responses = json.load(file)
all_data = []

for response_data in all_responses:
    businesses = response_data['businesses']
    
    for business in businesses:
        business_id = business['id']
        name = business['name']
        distance = round(business['distance'])
        address = business['location']['address1']
        city = business['location']['city']
        
        # Convert zip_code to integer or set to None
        try:
            zip_code = int(business['location']['zip_code'])
        except (ValueError, TypeError):
            zip_code = None
        
        latitude = business['coordinates']['latitude']
        longitude = business['coordinates']['longitude']
        rating = business['rating']
        review_count = business['review_count']
        
        categories = []
        
        if 'alias' in business['categories'][0]:
            category_name = business['categories'][0]['alias']
            categories.append(category_name)
        else:
            print("N/A")
        
        categories_str = ', '.join(categories)

        
        all_data.append({
            'name': name,
            'distance': distance,
            'address': address,
            'city': city,
            'zip_code': zip_code,
            'latitude': latitude,
            'longitude': longitude,
            'rating': rating,
            'review_count': review_count,
            'categories': categories_str 
        })

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df_yelp = pd.DataFrame(all_data)

df_yelp = df_yelp.drop_duplicates('name')

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# the Foursquare api provided less data for the city however, it provided categories other than food.
# the yelp api provided more data, however only for food related.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
yelp_sort_rating = df_yelp.sort_values("rating", ascending= False)
yelp_sort_review = yelp_sort_rating.sort_values("review_count", ascending= False)
yelp_sort_review.head(10)
#the most reviews with the highest ratings
# Out:
#                                            name  distance  \
# 0                               Gelbes Krokodil       543
# 74                                   Klosterhof       113
# 13                                    L'Osteria       205
# 53                          Josef das Stadtbräu       947
# 6                                         Cubus       468
# 14   Royal Bombay Palace - Indisches Restaurant      1281
# 3                         Steakhouse Restaurant       416
# 1                              Cocktailbar Easy       525
# 557                                      Walker       111
# 19                                Promenadenhof       206
#
#                    address  city  zip_code   latitude  longitude  rating  \
# 0            Dametzstr. 30  Linz    4020.0  48.302849  14.290824     4.5
# 74             Landstr. 30  Linz    4020.0  48.302190  14.289340     3.0
# 13            Promenade 22  Linz    4020.0  48.304278  14.286730     3.5
# 53             Landstr. 49  Linz    4020.0  48.299719  14.291365     3.0
# 6    Ars-Electronicastr. 1  Linz    4040.0  48.309700  14.284240     4.0
# 14         Goethestraße 34  Linz    4020.0  48.297340  14.296870     4.5
# 3     Untere Donaulände 12  Linz    4020.0  48.307890  14.289080     4.0
# 1          Baumbachstr. 14  Linz    4020.0  48.300818  14.284656     5.0
# 557          Hauptplatz 21  Linz    4020.0  48.305106  14.286525     3.5
# 19            Promenade 39  Linz    4020.0  48.303900  14.283400     3.5
#
#      review_count       categories
# 0              56  modern_european
# 74             49         austrian
# 13             46          italian
# 53             44       beergarden
# 6              36         austrian
# 14             34           indpak
# 3              28            steak
# 1              24     cocktailbars
# 557            24             bars
# 19             23    mediterranean

# %%
#there is no rating for restuarants in foursquare. also, the amount of data in foursquare in not comparable to yelp

df_foursquare
# Out:
#                                                name                   address  \
# 0                         Restaurant Bar Absolut!on                      Linz
# 1                         IKAAN Restaurant Bar Cafe               Altstadt 16
# 2    J. Leibetseder Restaurant- und BarbetriebsgmbH             Hauptplatz 12
# 3                          China-Restaurant Kim San              Hauptplatz 4
# 4                                 Restaurant Persia             Klosterstr. 1
# ..                                              ...                       ...
# 416                     Pferdehof Restaurant & Cafe  Ebelsberger Schloßweg 22
# 417                            Restaurant z Husaren        Traundorfer Str. 8
# 418                  Restaurant Volkshaus Ebelsberg  Kremsmünsterer Str. 1- 3
# 419                            Restaurant Pussy Cat       Wambacher Str. 50/1
# 422             City Wok Restaurant & Bar Yifeng MA            Lunaplatz 7- 9
#
#     zip_code   latitude  longitude                 categories
# 0       4030  48.305158  14.285047                         []
# 1       4020  48.304891  14.284415  [Café, Indian Restaurant]
# 2       4020  48.306419  14.286042               [Restaurant]
# 3       4020  48.306450  14.286628       [Chinese Restaurant]
# 4       4020  48.304685  14.286580               [Restaurant]
# ..       ...        ...        ...                        ...
# 416     4030  48.246007  14.333185                      [Inn]
# 417     4030  48.247310  14.341719         [Café, Restaurant]
# 418     4030  48.244087  14.329184         [BBQ Joint, Diner]
# 419     4030  48.246198  14.326622               [Restaurant]
# 422     4030  48.257436  14.360577         [Asian Restaurant]
#
# [89 rows x 6 columns]
